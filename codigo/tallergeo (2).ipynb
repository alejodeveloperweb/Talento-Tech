# %%
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import shapely as shp
import pandas as pd
print(gpd.__version__)
# Out:
# 0.14.3

# %%
#datasets/precios_combustible.csv: No such file or directory
#puede suceder el error documentado arriba de esta linea la solucion es poner un / al iniciar la ruta
ruta_municipios="/datasets/municipios.geojson"
ruta_precios="/datasets/precios_combustible.csv"

# %%
precios = gpd.read_file(ruta_precios)
shapes = gpd.read_file(ruta_municipios)

# %%
precios.head()
# Out:
#   departamentocodigo departamentonombre municipiocodigo municipionombre  \
# 0                 18            CAQUETA           18756          SOLANO
# 1                 99            VICHADA           99624   SANTA ROSALIA
# 2                 25       CUNDINAMARCA           25175            CHIA
# 3                 05          ANTIOQUIA           05837           TURBO
# 4                 47          MAGDALENA           47605        REMOLINO
#
#                                          agente  bandera  \
# 0                     COMERCIALIZADORA EL HUECO   TERPEL
# 1              ESTACION DE SERVICIO LA VICTORIA     BRIO
# 2  COMERCIAL SANTA INES LIMITADA EN LIQUIDACION   TERPEL
# 3                          BOMBA CODI EL PUEBLO  PROXXON
# 4                 ESTACION DE SERVICIOS LA RUTA     ECOS
#
#                                        direccion  \
# 0                               Puerto Principal
# 1             Carrera 9 con calle 3 No. 08-92-96
# 2                            CARRERA 1 No. 6A-60
# 3                                 CRA 13 99 A 41
# 4  FINCA EL CHORY ENTRADA A REMOLINO EN REMOLINO
#
#                        producto precio estado           fecharegistro geometry
# 0               BIODIESEL EXTRA   8500      1  01/08/2015 12:00:00 AM     None
# 1               BIODIESEL EXTRA   9000      1  01/08/2016 12:00:00 AM     None
# 2  GASOLINA CORRIENTE OXIGENADA   8060      1  01/04/2017 12:00:00 AM     None
# 3               BIODIESEL EXTRA   8893      1  05/07/2018 12:00:00 AM     None
# 4               BIODIESEL EXTRA   7500      1  01/28/2017 12:00:00 AM     None

# %%
shapes.plot()
# Out:
# <Axes: >

# %%
precios["producto"].unique()
precios_gasolina=precios[precios["producto"]=="GASOLINA CORRIENTE OXIGENADA"] #Filtrar por producto
print(len(precios_gasolina))
precios_gasolina.head()
# Out:
# 5291
#    departamentocodigo departamentonombre municipiocodigo  \
# 2                  25       CUNDINAMARCA           25175
# 5                  68          SANTANDER           68235
# 7                  47          MAGDALENA           47605
# 8                  95           GUAVIARE           95200
# 12                 52             NARIÑO           52256
#
#          municipionombre                                             agente  \
# 2                   CHIA       COMERCIAL SANTA INES LIMITADA EN LIQUIDACION
# 5   EL CARMEN DE CHUCURI  ESTACION DE SERVICIO EL PORVENIR CARMEN DE CHU...
# 7               REMOLINO                      ESTACION DE SERVICIOS LA RUTA
# 8             MIRAFLORES                ESTACION DE SERVICIO LA ESMERALDA 1
# 12            EL ROSARIO         ESTACION DE SERVICIO AUTOCENTRO ESMERALDAS
#
#    bandera                                      direccion  \
# 2   TERPEL                            CARRERA 1 No. 6A-60
# 5   TERPEL                    CORREGIMIENTO EL CENTENARIO
# 7     ECOS  FINCA EL CHORY ENTRADA A REMOLINO EN REMOLINO
# 8   TERPEL          VIA AEROPUERTO PRINCIPAL BARRIO CHINO
# 12  BIOMAX                     CORREGIMIENTO LA ESMERALDA
#
#                         producto precio estado           fecharegistro  \
# 2   GASOLINA CORRIENTE OXIGENADA   8060      1  01/04/2017 12:00:00 AM
# 5   GASOLINA CORRIENTE OXIGENADA   9080      1  01/22/2015 12:00:00 AM
# 7   GASOLINA CORRIENTE OXIGENADA   8300      1  01/28/2017 12:00:00 AM
# 8   GASOLINA CORRIENTE OXIGENADA  10900      1  01/29/2018 12:00:00 AM
# 12  GASOLINA CORRIENTE OXIGENADA   6500      1  01/24/2018 12:00:00 AM
#
#    geometry
# 2      None
# 5      None
# 7      None
# 8      None
# 12     None

# %%
precios_agrupados = precios_gasolina.groupby("municipionombre",as_index=False)["precio"].agg(["max"])
precios_mapa = shapes.merge(precios_agrupados, right_on="municipionombre", left_on="MPIO_CNMBR")

# %%
#Dibujar sobre el mapa
axis = shapes["geometry"].plot(figsize=(20, 12))
precios_mapa["max"] = precios_mapa["max"].apply(lambda x: int(x))
precios_mapa.plot(column="max", ax=axis, legend=True, scheme="Quantiles", cmap="gist_rainbow")
axis.set_title("Precios de  gasolina 2018")
# Out:
# Text(0.5, 1.0, 'Precios de  gasolina 2018')
